# %% [markdown]
# # Scraping Congress Members
#
# Reference and inspiration: https://github.com/lobodemonte/big-data-for-public-policy/blob/master/congress_gov_scraper/congress_gov_scraper.ipynb
#
# Information about all congress members in the house of representatives have been scraped from congress.gov using the code below, adjusted from the example in the link above to suit the needs of this project.

# %%
import json
import re
import requests
import pandas as pd 
import numpy as np
import urllib
import tqdm
from bs4 import BeautifulSoup

# %% [markdown]
# The approach is as follows:
# * Extract urls with lists of all relevant congress members
# * For each page, extract the url to each congress members' personal page from the link in the list

# %%
congress_numbers = [110, 111, 112, 113, 114, 115,116]
page_size = 250

# %%
# Generating urls with lists of congress members
def get_congress_url(congress_numbers, page_size, page):
    congress_q_str = "{" + '"congress":[{}]'.format(','.join('"{0}"'.format(num) for num in congress_numbers)) + "}"
    params= {
        "q": congress_q_str,
        "pageSize" : page_size,
        "page" : page,
        "searchResultViewType": "expanded",
        "KWICView": "true"
    }
    actual_params = urllib.parse.urlencode(params, safe='{}:[]')
    return "https://www.congress.gov/members?{}".format(actual_params)

def get_num_pages(soup):
    page_num_element = soup.find("div", {"class": "basic-search-tune-number"}).find("div", {"class": "pagination"}).find("span", {"class": "results-number"}).text
    page_num_raw = [int(s) for s in page_num_element.split() if s.isdigit()]
    return int(page_num_raw[0])

# %%
# Extract individual urls
def extract_member_name_url(entry):
    result_heading = entry.find("span", {"class": "result-heading"})
    member_name = result_heading.text
    if "Representative" in member_name:
        member_name = member_name.replace("Representative", "").strip()

    elif "Senator" in member_name:
        member_name = member_name.replace("Senator", "").strip()
    
    url = "https://www.congress.gov" + result_heading.a['href']
    return [member_name, url]   

def extract_congress_members(congress_list):
    members = []
    for entry in congress_list:
        member = {}
        [member["name"], member["url"]] = extract_member_name_url(entry)
        
        members.append(member)
    return members

# %%
congress_url = get_congress_url(congress_numbers, page_size, 1)
print("Congress URL: ", congress_url)

response = requests.get(congress_url).text
soup = BeautifulSoup(response, "html.parser")

num_pages = get_num_pages(soup)
print("Number of result pages: ", num_pages)
# Out:
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22110%22%2C%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=1&searchResultViewType=expanded&KWICView=true
# Number of result pages:  5

# %% [markdown]
# We run the functions, generating a long dictionary with all of the relevant congress members and their corresponding URL

# %%
#Now that we know how many pages we'll scrape, we can start scraping
congress_url = get_congress_url(congress_numbers, page_size, 1)
print("Congress URL: ", congress_url)

response = requests.get(congress_url).text
soup = BeautifulSoup(response, "html.parser")

#We need the number of pages we will need to scrape
num_pages = get_num_pages(soup)
print("Number of result pages: ", num_pages)

all_members = []
for page in range(1, num_pages+1):
    congress_url = get_congress_url(congress_numbers, page_size, page)
    print("Congress URL: ", congress_url)
    
    response = requests.get(congress_url).text
    soup = BeautifulSoup(response, "html.parser")
    
    congress_list = soup.find("ol", {"class": "basic-search-results-lists"}).find_all("li", {"class": "expanded"})

    print("Page Size: {}, Members found: {}".format(page_size, len(congress_list)))

    members = extract_congress_members(congress_list)
    print("Extracted {} congressional entries from Page {}".format(len(members), page))
    all_members.extend(members)
# Out:
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22110%22%2C%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=1&searchResultViewType=expanded&KWICView=true
# Number of result pages:  5
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22110%22%2C%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=1&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 1
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22110%22%2C%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=2&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 2
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22110%22%2C%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=3&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 3
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22110%22%2C%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=4&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 4
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22110%22%2C%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=5&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 89
# Extracted 89 congressional entries from Page 5

# %%
congress_members_urls = pd.DataFrame(all_members)
congress_members_urls.drop_duplicates(ignore_index=True, inplace=True)
congress_members_urls
# Out:
#                     name                                                url
# 0      Abercrombie, Neil  https://www.congress.gov/member/neil-abercromb...
# 1     Abraham, Ralph Lee  https://www.congress.gov/member/ralph-abraham/...
# 2      Ackerman, Gary L.  https://www.congress.gov/member/gary-ackerman/...
# 3         Adams, Alma S.  https://www.congress.gov/member/alma-adams/A00...
# 4           Adams, Sandy  https://www.congress.gov/member/sandy-adams/A0...
# ...                  ...                                                ...
# 1084        Young, David  https://www.congress.gov/member/david-young/Y0...
# 1085          Young, Don  https://www.congress.gov/member/don-young/Y000033
# 1086         Young, Todd  https://www.congress.gov/member/todd-young/Y00...
# 1087      Zeldin, Lee M.  https://www.congress.gov/member/lee-zeldin/Z00...
# 1088      Zinke, Ryan K.  https://www.congress.gov/member/ryan-zinke/Z00...
#
# [1089 rows x 2 columns]

# %% [markdown]
# Finally, for each member, we open their URL and extract the relevant information from the HTML. In this case we are looking for:
# * Party
# * Champer (to ensure they are part of the house of representatives)
# * District
# * Congress numbers
# * Time period

# %%
def parse_profile(soup):
    results = []
    remove_endings = ['th', 'st', 'nd', 'rd']

    profile = soup.find("div", {"class": "overview-member-column-profile member_profile"})
    party_table = profile.find("table", {"class": "standard01 nomargin"})

    for row in party_table.find_all("tr"):
        if row.find('th', {"class":"member_party"}):
            party = row.find('td').text.strip()
            
        if row.find('th', {"class":"member_chamber"}):
            chamber = row.find('th', {"class":"member_chamber"}).text.strip()
            if chamber == 'House':
                res = row.find('td').text.strip()
                if res:
                    state = res.split(",")[0]
                    rest = res.split(",")[1]
                    district = rest.split(" ")[2]
                    if district == 'At':
                        district = 'At Large'
                        congress_numbers = [int(s[:-2]) for s in rest.split(" ")[4].split("-") if s[:-2].isdigit()]

                    else:
                        congress_numbers = [int(s[:-2]) for s in rest.split(" ")[3].split("-") if s[:-2].isdigit()]
                    
                    if len(congress_numbers) > 1:
                        congress_numbers = list(range(congress_numbers[0], congress_numbers[1] + 1))

                    years_str = rest[rest.find("(")+1:rest.find(")")]
                    years = years_str.split("-")
                    if len(years) == 1:
                        start = years[0]
                        end = years[0]
                    if len(years) == 2:
                        start = years[0]
                        end = years[1]
                    if end == 'Present':
                        end = np.inf

                    results.append([party, state, district, chamber, congress_numbers, start, end])
    return results

# %% [markdown]
# We iterate over the dataframe containing all the congress members, extracting their individual information for each iteration, which takes a bit of time.

# %%
columns=['name','url', 'party','state','district','chamber', 'congress_numbers', 'start', 'end']
congress_member_info = pd.DataFrame()
for index, row in congress_members_urls.iterrows():
    name = row['name']
    url = row['url']
    print(name)
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")
    terms = parse_profile(soup)
    for term in terms:
        to_add = [name,url]
        to_add.extend(term)
        to_add = pd.Series(to_add, columns)
        congress_member_info = congress_member_info.append([to_add], ignore_index=True)
# Out:
# Abercrombie, Neil
# Abraham, Ralph Lee
# Ackerman, Gary L.
# Adams, Alma S.
# Adams, Sandy
# Aderholt, Robert B.
# Adler, John H.
# Aguilar, Pete
# Akaka, Daniel K.
# Akin, W. Todd
# Alexander, Lamar
# Alexander, Rodney
# Allard, Wayne
# Allen, Rick W.
# Allen, Thomas H.
# Allred, Colin Z.
# Altmire, Jason
# Amash, Justin
# Amodei, Mark E.
# Andrews, Robert E.
# Arcuri, Michael A.
# Armstrong, Kelly
# Arrington, Jodey C.
# Ashford, Brad
# Austria, Steve
# Axne, Cynthia
# Ayotte, Kelly
# Babin, Brian
# Baca, Joe
# Bachmann, Michele
# Bachus, Spencer
# Bacon, Don
# Baird, Brian
# Baird, James R.
# Baker, Richard H.
# Balderson, Troy
# Baldwin, Tammy
# Banks, Jim
# Barber, Ron
# Barletta, Lou
# Barr, Andy
# Barragan, Nanette Diaz
# Barrasso, John
# Barrett, J. Gresham
# Barrow, John
# Bartlett, Roscoe G.
# Barton, Joe
# Bass, Charles F.
# Bass, Karen
# Baucus, Max
# Bayh, Evan
# Bean, Melissa L.
# Beatty, Joyce
# Becerra, Xavier
# Begich, Mark
# Benishek, Dan
# Bennet, Michael F.
# Bennett, Robert F.
# Bentivolio, Kerry L.
# Bera, Ami
# Berg, Rick
# Bergman, Jack
# Berkley, Shelley
# Berman, Howard L.
# Berry, Marion
# Beyer, Donald S., Jr.
# Biden, Joseph R., Jr.
# Biggert, Judy
# Biggs, Andy
# Bilbray, Brian P.
# Bilirakis, Gus M.
# Bingaman, Jeff
# Bishop, Dan
# Bishop, Mike
# Bishop, Rob
# Bishop, Sanford D., Jr.
# Bishop, Timothy H.
# Black, Diane
# Blackburn, Marsha
# Blum, Rod
# Blumenauer, Earl
# Blumenthal, Richard
# Blunt Rochester, Lisa
# Blunt, Roy
# Boccieri, John A.
# Boehner, John A.
# Bonamici, Suzanne
# Bond, Christopher S.
# Bonner, Jo
# Bono Mack, Mary
# Booker, Cory A.
# Boozman, John
# Delegate Bordallo, Madeleine Z.
# Boren, Dan
# Bost, Mike
# Boswell, Leonard L.
# Boucher, Rick
# Boustany, Charles W., Jr.
# Boxer, Barbara
# Boyd, Allen
# Boyda, Nancy E.
# Boyle, Brendan F.
# Brady, Kevin
# Brady, Robert A.
# Braley, Bruce L.
# Brat, Dave
# Braun, Mike
# Bridenstine, Jim
# Bright, Bobby
# Brindisi, Anthony
# Brooks, Mo
# Brooks, Susan W.
# Broun, Paul C.
# Brown, Anthony G.
# Brown, Corrine
# Brown, Henry E., Jr.
# Brown, Scott P.
# Brown, Sherrod
# Brown-Waite, Ginny
# Brownback, Sam
# Brownley, Julia
# Buchanan, Vern
# Buck, Ken
# Bucshon, Larry
# Budd, Ted
# Buerkle, Ann Marie
# Bunning, Jim
# Burchett, Tim
# Burgess, Michael C.
# Burr, Richard
# Burris, Roland
# Burton, Dan
# Bustos, Cheri
# Butterfield, G. K.
# Buyer, Steve
# Byrd, Robert C.
# Byrne, Bradley
# Calvert, Ken
# Camp, Dave
# Campbell, John
# Cannon, Chris
# Canseco, Francisco "Quico"
# Cantor, Eric
# Cantwell, Maria
# Cao, Anh "Joseph"
# Capito, Shelley Moore
# Capps, Lois
# Capuano, Michael E.
# Carbajal, Salud O.
# Cardenas, Tony
# Cardin, Benjamin L.
# Cardoza, Dennis A.
# Carnahan, Russ
# Carney, Christopher P.
# Carney, John C., Jr.
# Carper, Thomas R.
# Carson, Andre
# Carson, Julia
# Carter, Earl L. "Buddy"
# Carter, John R.
# Cartwright, Matt
# Case, Ed
# Casey, Robert P., Jr.
# Cassidy, Bill
# Casten, Sean
# Castle, Michael N.
# Castor, Kathy
# Castro, Joaquin
# Cazayoux, Donald J., Jr.
# Chabot, Steve
# Chaffetz, Jason
# Chambliss, Saxby
# Chandler, Ben
# Cheney, Liz
# Chiesa, Jeff
# Childers, Travis
# Delegate Christensen, Donna M.
# Chu, Judy
# Cicilline, David N.
# Cisneros, Gilbert Ray, Jr.
# Clark, Katherine M.
# Clarke, Hansen
# Clarke, Yvette D.
# Clawson, Curt
# Clay, Wm. Lacy
# Cleaver, Emanuel
# Cline, Ben
# Clinton, Hillary Rodham
# Cloud, Michael
# Clyburn, James E.
# Coats, Daniel
# Coble, Howard
# Coburn, Tom
# Cochran, Thad
# Coffman, Mike
# Cohen, Steve
# Cole, Tom
# Coleman, Norm
# Collins, Chris
# Collins, Doug
# Collins, Susan M.
# Comer, James
# Comstock, Barbara
# Conaway, K. Michael
# Connolly, Gerald E.
# Conrad, Kent
# Conyers, John, Jr.
# Cook, Paul
# Coons, Christopher A.
# Cooper, Jim
# Corker, Bob
# Cornyn, John
# Correa, J. Luis
# Cortez Masto, Catherine
# Costa, Jim
# Costello, Jerry F.
# Costello, Ryan A.
# Cotton, Tom
# Courtney, Joe
# Cowan, William M.
# Cox, TJ
# Craig, Angie
# Craig, Larry E.
# Cramer, Kevin
# Cramer, Robert E. (Bud), Jr.
# Crapo, Mike
# Cravaack, Chip
# Crawford, Eric A. "Rick"
# Crenshaw, Ander
# Crenshaw, Dan
# Crist, Charlie
# Critz, Mark S.
# Crow, Jason
# Crowley, Joseph
# Cruz, Ted
# Cubin, Barbara
# Cuellar, Henry
# Culberson, John Abney
# Cummings, Elijah E.
# Cunningham, Joe
# Curbelo, Carlos
# Curson, David Alan
# Curtis, John R.
# Dahlkemper, Kathleen A.
# Daines, Steve
# Davids, Sharice
# Davidson, Warren
# Davis, Artur
# Davis, Danny K.
# Davis, David
# Davis, Geoff
# Davis, Jo Ann
# Davis, Lincoln
# Davis, Rodney
# Davis, Susan A.
# Davis, Tom
# Deal, Nathan
# Dean, Madeleine
# DeFazio, Peter A.
# DeGette, Diana
# Delahunt, Bill
# Delaney, John K.
# DeLauro, Rosa L.
# DelBene, Suzan K.
# Delgado, Antonio
# Demings, Val Butler
# DeMint, Jim
# Denham, Jeff
# Dent, Charles W.
# DeSantis, Ron
# DeSaulnier, Mark
# DesJarlais, Scott
# Deutch, Theodore E.
# Diaz-Balart, Lincoln
# Diaz-Balart, Mario
# Dicks, Norman D.
# Dingell, Debbie
# Dingell, John D.
# Djou, Charles K.
# Dodd, Christopher J.
# Doggett, Lloyd
# Dold, Robert J.
# Dole, Elizabeth
# Domenici, Pete V.
# Donnelly, Joe
# Donovan, Daniel M., Jr.
# Doolittle, John T.
# Dorgan, Byron L.
# Doyle, Michael F.
# Drake, Thelma D.
# Dreier, David
# Driehaus, Steve
# Duckworth, Tammy
# Duffy, Sean P.
# Duncan, Jeff
# Duncan, John J., Jr.
# Dunn, Neal P.
# Durbin, Richard J.
# Edwards, Chet
# Edwards, Donna F.
# Ehlers, Vernon J.
# Ellison, Keith
# Ellmers, Renee L.
# Ellsworth, Brad
# Emanuel, Rahm
# Emerson, Jo Ann
# Emmer, Tom
# Engel, Eliot L.
# English, Phil
# Ensign, John
# Enyart, William L.
# Enzi, Michael B.
# Ernst, Joni
# Escobar, Veronica
# Eshoo, Anna G.
# Espaillat, Adriano
# Estes, Ron
# Esty, Elizabeth H.
# Etheridge, Bob
# Evans, Dwight
# Everett, Terry
# Delegate Faleomavaega, Eni F. H.
# Fallin, Mary
# Farenthold, Blake
# Farr, Sam
# Faso, John J.
# Fattah, Chaka
# Feeney, Tom
# Feingold, Russell D.
# Feinstein, Dianne
# Ferguson, A. Drew, IV
# Ferguson, Mike
# Filner, Bob
# Fincher, Stephen Lee
# Finkenauer, Abby
# Fischer, Deb
# Fitzpatrick, Brian K.
# Fitzpatrick, Michael G.
# Flake, Jeff
# Fleischmann, Charles J. "Chuck"
# Fleming, John
# Fletcher, Lizzie
# Flores, Bill
# Forbes, J. Randy
# Fortenberry, Jeff
# Resident Commissioner Fortuno, Luis G.
# Fossella, Vito
# Foster, Bill
# Foxx, Virginia
# Frank, Barney
# Frankel, Lois
# Franken, Al
# Franks, Trent
# Frelinghuysen, Rodney P.
# Fudge, Marcia L.
# Fulcher, Russ
# Gabbard, Tulsi
# Gaetz, Matt
# Gallagher, Mike
# Gallegly, Elton
# Gallego, Pete P.
# Gallego, Ruben
# Garamendi, John
# Garcia, Jesus G. "Chuy"
# Garcia, Joe
# Garcia, Mike
# Garcia, Sylvia R.
# Gardner, Cory
# Garrett, Scott
# Garrett, Thomas A., Jr.
# Gerlach, Jim
# Gianforte, Greg
# Gibbs, Bob
# Gibson, Christopher P.
# Giffords, Gabrielle
# Gilchrest, Wayne T.
# Gillibrand, Kirsten E.
# Gillmor, Paul E.
# Gingrey, Phil
# Gohmert, Louie
# Golden, Jared F.
# Gomez, Jimmy
# Gonzalez, Anthony
# Gonzalez, Charles A.
# Gonzalez, Vicente
# Resident Commissioner Gonzalez-Colon, Jenniffer
# Goode, Virgil H., Jr.
# Gooden, Lance
# Goodlatte, Bob
# Goodwin, Carte Patrick
# Gordon, Bart
# Gosar, Paul A.
# Gottheimer, Josh
# Gowdy, Trey
# Graham, Gwen
# Graham, Lindsey
# Granger, Kay
# Grassley, Chuck
# Graves, Garret
# Graves, Sam
# Graves, Tom
# Grayson, Alan
# Green, Al
# Green, Gene
# Green, Mark E.
# Gregg, Judd
# Griffin, Tim
# Griffith, H. Morgan
# Griffith, Parker
# Grijalva, Raul M.
# Grimm, Michael G.
# Grothman, Glenn
# Guest, Michael
# Guinta, Frank C.
# Guthrie, Brett
# Gutierrez, Luis V.
# Haaland, Debra A.
# Hagan, Kay R.
# Hagedorn, Jim
# Hagel, Chuck
# Hahn, Janice
# Hall, John J.
# Hall, Ralph M.
# Halvorson, Deborah L.
# Hanabusa, Colleen
# Handel, Karen C.
# Hanna, Richard L.
# Harder, Josh
# Hardy, Cresent
# Hare, Phil
# Harkin, Tom
# Harman, Jane
# Harper, Gregg
# Harris, Andy
# Harris, Kamala D.
# Hartzler, Vicky
# Hassan, Margaret Wood
# Hastert, J. Dennis
# Hastings, Alcee L.
# Hastings, Doc
# Hatch, Orrin G.
# Hawley, Josh
# Hayes, Jahana
# Hayes, Robin
# Hayworth, Nan A. S.
# Heck, Denny
# Heck, Joseph J.
# Heinrich, Martin
# Heitkamp, Heidi
# Heller, Dean
# Hensarling, Jeb
# Herger, Wally
# Hern, Kevin
# Herrera Beutler, Jaime
# Herseth Sandlin, Stephanie
# Hice, Jody B.
# Higgins, Brian
# Higgins, Clay
# Hill, Baron P.
# Hill, J. French
# Hill, Katie
# Himes, James A.
# Hinchey, Maurice D.
# Hinojosa, Ruben
# Hirono, Mazie K.
# Hobson, David L.
# Hochul, Kathleen C.
# Hodes, Paul W.
# Hoekstra, Peter
# Hoeven, John
# Holden, Tim
# Holding, George
# Hollingsworth, Trey
# Holt, Rush
# Honda, Michael M.
# Hooley, Darlene
# Horn, Kendra S.
# Horsford, Steven
# Houlahan, Chrissy
# Hoyer, Steny H.
# Hudson, Richard
# Huelskamp, Tim
# Huffman, Jared
# Huizenga, Bill
# Hulshof, Kenny C.
# Hultgren, Randy
# Hunter, Duncan
# Hunter, Duncan D.
# Hurd, Will
# Hurt, Robert
# Hutchison, Kay Bailey
# Hyde-Smith, Cindy
# Inglis, Bob
# Inhofe, James M.
# Inouye, Daniel K.
# Inslee, Jay
# Isakson, Johnny
# Israel, Steve
# Issa, Darrell E.
# Jackson Lee, Sheila
# Jackson, Jesse L., Jr.
# Jacobs, Chris
# Jayapal, Pramila
# Jefferson, William J.
# Jeffries, Hakeem S.
# Jenkins, Evan H.
# Jenkins, Lynn
# Jindal, Bobby
# Johanns, Mike
# Johnson, Bill
# Johnson, Dusty
# Johnson, Eddie Bernice
# Johnson, Henry C. "Hank," Jr.
# Johnson, Mike
# Johnson, Ron
# Johnson, Sam
# Johnson, Tim
# Johnson, Timothy V.
# Jolly, David W.
# Jones, Brenda
# Jones, Doug
# Jones, Stephanie Tubbs
# Jones, Walter B., Jr.
# Jordan, Jim
# Joyce, David P.
# Joyce, John
# Kagen, Steve
# Kaine, Tim
# Kanjorski, Paul E.
# Kaptur, Marcy
# Katko, John
# Kaufman, Edward E.
# Keating, William R.
# Keller, Fred
# Keller, Ric
# Kelly, Mike
# Kelly, Robin L.
# Kelly, Trent
# Kennedy, Edward M.
# Kennedy, John
# Kennedy, Joseph P., III
# Kennedy, Patrick J.
# Kerry, John F.
# Khanna, Ro
# Kihuen, Ruben J.
# Kildee, Dale E.
# Kildee, Daniel T.
# Kilmer, Derek
# Kilpatrick, Carolyn C.
# Kilroy, Mary Jo
# Kim, Andy
# Kind, Ron
# King, Angus S., Jr.
# King, Peter T.
# King, Steve
# Kingston, Jack
# Kinzinger, Adam
# Kirk, Mark Steven
# Kirk, Paul Grattan, Jr.
# Kirkpatrick, Ann
# Kissell, Larry
# Klein, Ron
# Kline, John
# Klobuchar, Amy
# Knight, Stephen
# Knollenberg, Joe
# Kohl, Herb
# Kosmas, Suzanne M.
# Kratovil, Frank, Jr.
# Krishnamoorthi, Raja
# Kucinich, Dennis J.
# Kuhl, John R. "Randy", Jr.
# Kuster, Ann M.
# Kustoff, David
# Kyl, Jon
# Labrador, Raul R.
# LaHood, Darin
# LaHood, Ray
# LaMalfa, Doug
# Lamb, Conor
# Lamborn, Doug
# Lampson, Nick
# Lance, Leonard
# Landrieu, Mary L.
# Landry, Jeffrey M.
# Langevin, James R.
# Lankford, James
# Lantos, Tom
# Larsen, Rick
# Larson, John B.
# Latham, Tom
# LaTourette, Steven C.
# Latta, Robert E.
# Lautenberg, Frank R.
# Lawrence, Brenda L.
# Lawson, Al, Jr.
# Leahy, Patrick J.
# Lee, Barbara
# Lee, Christopher J.
# Lee, Mike
# Lee, Susie
# LeMieux, George S.
# Lesko, Debbie
# Levin, Andy
# Levin, Carl
# Levin, Mike
# Levin, Sander M.
# Lewis, Jason
# Lewis, Jerry
# Lewis, John
# Lewis, Ron
# Lieberman, Joseph I.
# Lieu, Ted
# Lincoln, Blanche L.
# Linder, John
# Lipinski, Daniel
# LoBiondo, Frank A.
# Loebsack, David
# Loeffler, Kelly
# Lofgren, Zoe
# Long, Billy
# Lott, Trent
# Loudermilk, Barry
# Love, Mia B.
# Lowenthal, Alan S.
# Lowey, Nita M.
# Lucas, Frank D.
# Luetkemeyer, Blaine
# Lugar, Richard G.
# Lujan Grisham, Michelle
# Lujan, Ben Ray
# Lummis, Cynthia M.
# Lungren, Daniel E.
# Luria, Elaine G.
# Lynch, Stephen F.
# MacArthur, Thomas
# Mack, Connie
# Maffei, Daniel B.
# Mahoney, Tim
# Malinowski, Tom
# Maloney, Carolyn B.
# Maloney, Sean Patrick
# Manchin, Joe, III
# Manzullo, Donald A.
# Marchant, Kenny
# Marino, Tom
# Markey, Betsy
# Markey, Edward J.
# Marshall, Jim
# Marshall, Roger W.
# Martinez, Mel
# Massa, Eric J. J.
# Massie, Thomas
# Mast, Brian J.
# Matheson, Jim
# Matsui, Doris O.
# McAdams, Ben
# McAllister, Vance M.
# McBath, Lucy
# McCain, John
# McCarthy, Carolyn
# McCarthy, Kevin
# McCaskill, Claire
# McCaul, Michael T.
# McClintock, Tom
# McCollum, Betty
# McConnell, Mitch
# McCotter, Thaddeus G.
# McCrery, Jim
# McDermott, Jim
# McEachin, A. Donald
# McGovern, James P.
# McHenry, Patrick T.
# McHugh, John M.
# McIntyre, Mike
# McKeon, Howard P. "Buck"
# McKinley, David B.
# McMahon, Michael E.
# McMorris Rodgers, Cathy
# McNerney, Jerry
# McNulty, Michael R.
# McSally, Martha
# Meadows, Mark
# Meehan, Martin T.
# Meehan, Patrick
# Meek, Kendrick B.
# Meeks, Gregory W.
# Melancon, Charlie
# Menendez, Robert
# Meng, Grace
# Merkley, Jeff
# Messer, Luke
# Meuser, Daniel
# Mfume, Kweisi
# Mica, John L.
# Michaud, Michael H.
# Mikulski, Barbara A.
# Millender-McDonald, Juanita
# Miller, Brad
# Miller, Candice S.
# Miller, Carol D.
# Miller, Gary G.
# Miller, George
# Miller, Jeff
# Minnick, Walter
# Mitchell, Harry E.
# Mitchell, Paul
# Mollohan, Alan B.
# Moolenaar, John R.
# Mooney, Alexander X.
# Moore, Dennis
# Moore, Gwen
# Moran, James P.
# Moran, Jerry
# Morelle, Joseph D.
# Moulton, Seth
# Mucarsel-Powell, Debbie
# Mullin, Markwayne
# Mulvaney, Mick
# Murkowski, Lisa
# Murphy, Christopher
# Murphy, Gregory
# Murphy, Patrick
# Murphy, Patrick J.
# Murphy, Scott
# Murphy, Stephanie N.
# Murphy, Tim
# Murray, Patty
# Murtha, John P.
# Musgrave, Marilyn N.
# Myrick, Sue Wilkins
# Nadler, Jerrold
# Napolitano, Grace F.
# Neal, Richard E.
# Negrete McLeod, Gloria
# Neguse, Joe
# Nelson, Ben
# Nelson, Bill
# Neugebauer, Randy
# Newhouse, Dan
# Noem, Kristi L.
# Nolan, Richard M.
# Norcross, Donald
# Norman, Ralph
# Delegate Norton, Eleanor Holmes
# Norwood, Charles W.
# Nugent, Richard B.
# Nunes, Devin
# Nunnelee, Alan
# Nye, Glenn C.
# O'Halleran, Tom
# O'Rourke, Beto
# Obama, Barack
# Oberstar, James L.
# Obey, David R.
# Ocasio-Cortez, Alexandria
# Olson, Pete
# Olver, John W.
# Omar, Ilhan
# Ortiz, Solomon P.
# Owens, William L.
# Palazzo, Steven M.
# Pallone, Frank, Jr.
# Palmer, Gary J.
# Panetta, Jimmy
# Pappas, Chris
# Pascrell, Bill, Jr.
# Pastor, Ed
# Paul, Rand
# Paul, Ron
# Paulsen, Erik
# Payne, Donald M.
# Payne, Donald M., Jr.
# Pearce, Stevan
# Pelosi, Nancy
# Pence, Greg
# Pence, Mike
# Perdue, David
# Perlmutter, Ed
# Perriello, Thomas S.P.
# Perry, Scott
# Peters, Gary C.
# Peters, Scott H.
# Peterson, Collin C.
# Peterson, John E.
# Petri, Thomas E.
# Phillips, Dean
# Pickering, Charles W. "Chip"
# Resident Commissioner Pierluisi, Pedro R.
# Pingree, Chellie
# Pittenger, Robert
# Pitts, Joseph R.
# Delegate Plaskett, Stacey E.
# Platts, Todd Russell
# Pocan, Mark
# Poe, Ted
# Poliquin, Bruce
# Polis, Jared
# Pomeroy, Earl
# Pompeo, Mike
# Porter, Jon C.
# Porter, Katie
# Portman, Rob
# Posey, Bill
# Pressley, Ayanna
# Price, David E.
# Price, Tom
# Pryce, Deborah
# Pryor, Mark L.
# Putnam, Adam H.
# Quayle, Benjamin
# Quigley, Mike
# Radanovich, George
# Radel, Trey
# Delegate Radewagen, Aumua Amata Coleman
# Rahall, Nick J., II
# Ramstad, Jim
# Rangel, Charles B.
# Raskin, Jamie
# Ratcliffe, John
# Reed, Jack
# Reed, Tom
# Regula, Ralph
# Rehberg, Denny
# Reichert, David G.
# Reid, Harry
# Renacci, James B.
# Renzi, Rick
# Reschenthaler, Guy
# Reyes, Silvestre
# Reynolds, Thomas M.
# Ribble, Reid J.
# Rice, Kathleen M.
# Rice, Tom
# Richardson, Laura
# Richmond, Cedric L.
# Rigell, E. Scott
# Riggleman, Denver
# Risch, James E.
# Rivera, David
# Roberts, Pat
# Roby, Martha
# Rockefeller, John D., IV
# Rodriguez, Ciro D.
# Roe, David P.
# Rogers, Harold
# Rogers, Mike D.
# Rogers, Mike J.
# Rohrabacher, Dana
# Rokita, Todd
# Romney, Mitt
# Rooney, Francis
# Rooney, Thomas J.
# Ros-Lehtinen, Ileana
# Rose, John W.
# Rose, Max
# Rosen, Jacky
# Roskam, Peter J.
# Ross, Dennis A.
# Ross, Mike
# Rothfus, Keith J.
# Rothman, Steven R.
# Rouda, Harley
# Rounds, Mike
# Rouzer, David
# Roy, Chip
# Roybal-Allard, Lucille
# Royce, Edward R.
# Rubio, Marco
# Ruiz, Raul
# Runyan, Jon
# Ruppersberger, C. A. Dutch
# Rush, Bobby L.
# Russell, Steve
# Rutherford, John H.
# Ryan, Paul D.
# Ryan, Tim
# Delegate Sablan, Gregorio Kilili Camacho
# Salazar, John T.
# Salazar, Ken
# Sali, Bill
# Salmon, Matt
# Delegate San Nicolas, Michael F. Q.
# Sanchez, Linda T.
# Sanchez, Loretta
# Sanders, Bernard
# Sanford, Mark
# Sarbanes, John P.
# Sasse, Ben
# Saxton, Jim
# Scalise, Steve
# Scanlon, Mary Gay
# Schakowsky, Janice D.
# Schatz, Brian
# Schauer, Mark H.
# Schiff, Adam B.
# Schilling, Robert T.
# Schmidt, Jean
# Schneider, Bradley Scott
# Schock, Aaron
# Schrader, Kurt
# Schrier, Kim
# Schumer, Charles E.
# Schwartz, Allyson Y.
# Schweikert, David
# Scott, Austin
# Scott, David
# Scott, Rick
# Scott, Robert C. "Bobby"
# Scott, Tim
# Sensenbrenner, F. James, Jr.
# Serrano, Jose E.
# Sessions, Jeff
# Sessions, Pete
# Sestak, Joe
# Sewell, Terri A.
# Shadegg, John B.
# Shaheen, Jeanne
# Shalala, Donna E.
# Shays, Christopher
# Shea-Porter, Carol
# Shelby, Richard C.
# Sherman, Brad
# Sherrill, Mikie
# Shimkus, John
# Shuler, Heath
# Shuster, Bill
# Simpson, Michael K.
# Sinema, Kyrsten
# Sires, Albio
# Skelton, Ike
# Slaughter, Louise McIntosh
# Slotkin, Elissa
# Smith, Adam
# Smith, Adrian
# Smith, Christopher H.
# Smith, Gordon H.
# Smith, Jason
# Smith, Lamar
# Smith, Tina
# Smucker, Lloyd
# Snowe, Olympia J.
# Snyder, Vic
# Solis, Hilda L.
# Soto, Darren
# Souder, Mark E.
# Southerland, Steve II
# Space, Zachary T.
# Spanberger, Abigail Davis
# Spano, Ross
# Specter, Arlen
# Speier, Jackie
# Spratt, John M., Jr.
# Stabenow, Debbie
# Stanton, Greg
# Stark, Fortney Pete
# Stauber, Pete
# Stearns, Cliff
# Stefanik, Elise M.
# Steil, Bryan
# Steube, W. Gregory
# Stevens, Haley M.
# Stevens, Ted
# Stewart, Chris
# Stivers, Steve
# Stockman, Steve
# Strange, Luther
# Stupak, Bart
# Stutzman, Marlin A.
# Sullivan, Dan
# Sullivan, John
# Sununu, John E.
# Suozzi, Thomas R.
# Sutton, Betty
# Swalwell, Eric
# Takai, Mark
# Takano, Mark
# Tancredo, Thomas G.
# Tanner, John S.
# Tauscher, Ellen O.
# Taylor, Gene
# Taylor, Scott
# Taylor, Van
# Teague, Harry
# Tenney, Claudia
# Terry, Lee
# Tester, Jon
# Thomas, Craig
# Thompson, Bennie G.
# Thompson, Glenn
# Thompson, Mike
# Thornberry, Mac
# Thune, John
# Tiahrt, Todd
# Tiberi, Patrick J.
# Tierney, John F.
# Tiffany, Thomas P.
# Tillis, Thom
# Timmons, William R. IV
# Tipton, Scott R.
# Titus, Dina
# Tlaib, Rashida
# Tonko, Paul
# Toomey, Pat
# Torres Small, Xochitl
# Torres, Norma J.
# Towns, Edolphus
# Trahan, Lori
# Trone, David J.
# Trott, David A.
# Tsongas, Niki
# Turner, Michael R.
# Turner, Robert L.
# Udall, Mark
# Udall, Tom
# Underwood, Lauren
# Upton, Fred
# Valadao, David G.
# Van Drew, Jefferson
# Van Hollen, Chris
# Vargas, Juan
# Veasey, Marc A.
# Vela, Filemon
# Velazquez, Nydia M.
# Visclosky, Peter J.
# Vitter, David
# Voinovich, George V.
# Wagner, Ann
# Walberg, Tim
# Walden, Greg
# Walker, Mark
# Walorski, Jackie
# Walsh, James T.
# Walsh, Joe
# Walsh, John E.
# Walters, Mimi
# Waltz, Michael
# Walz, Timothy J.
# Wamp, Zach
# Warner, John
# Warner, Mark R.
# Warren, Elizabeth
# Wasserman Schultz, Debbie
# Waters, Maxine
# Watkins, Steve
# Watson Coleman, Bonnie
# Watson, Diane E.
# Watt, Melvin L.
# Waxman, Henry A.
# Webb, Jim
# Weber, Randy K., Sr.
# Webster, Daniel
# Weiner, Anthony D.
# Welch, Peter
# Weldon, Dave
# Weller, Jerry
# Wenstrup, Brad R.
# West, Allen B.
# Westerman, Bruce
# Westmoreland, Lynn A.
# Wexler, Robert
# Wexton, Jennifer
# Whitehouse, Sheldon
# Whitfield, Ed
# Wicker, Roger F.
# Wild, Susan
# Williams, Roger
# Wilson, Charles A.
# Wilson, Frederica S.
# Wilson, Heather
# Wilson, Joe
# Wittman, Robert J.
# Wolf, Frank R.
# Womack, Steve
# Woodall, Rob
# Woolsey, Lynn C.
# Wright, Ron
# Wu, David
# Wyden, Ron
# Wynn, Albert Russell
# Yarmuth, John A.
# Yoder, Kevin
# Yoho, Ted S.
# Young, C. W. Bill
# Young, David
# Young, Don
# Young, Todd
# Zeldin, Lee M.
# Zinke, Ryan K.

# %%
congress_member_info
# Out:
#                     name                                                url  \
# 0      Abercrombie, Neil  https://www.congress.gov/member/neil-abercromb...
# 1     Abraham, Ralph Lee  https://www.congress.gov/member/ralph-abraham/...
# 2      Ackerman, Gary L.  https://www.congress.gov/member/gary-ackerman/...
# 3         Adams, Alma S.  https://www.congress.gov/member/alma-adams/A00...
# 4           Adams, Sandy  https://www.congress.gov/member/sandy-adams/A0...
# ...                  ...                                                ...
# 1062        Young, David  https://www.congress.gov/member/david-young/Y0...
# 1063          Young, Don  https://www.congress.gov/member/don-young/Y000033
# 1064         Young, Todd  https://www.congress.gov/member/todd-young/Y00...
# 1065      Zeldin, Lee M.  https://www.congress.gov/member/lee-zeldin/Z00...
# 1066      Zinke, Ryan K.  https://www.congress.gov/member/ryan-zinke/Z00...
#
#            party           state  district chamber  \
# 0     Democratic          Hawaii         1   House
# 1     Republican       Louisiana         5   House
# 2     Democratic        New York         5   House
# 3     Democratic  North Carolina        12   House
# 4     Republican         Florida        24   House
# ...          ...             ...       ...     ...
# 1062  Republican            Iowa         3   House
# 1063  Republican          Alaska  At Large   House
# 1064  Republican         Indiana         9   House
# 1065  Republican        New York         1   House
# 1066  Republican         Montana  At Large   House
#
#                                        congress_numbers start   end
# 0     [102, 103, 104, 105, 106, 107, 108, 109, 110, ...  1991  2011
# 1                                       [114, 115, 116]  2015   inf
# 2     [103, 104, 105, 106, 107, 108, 109, 110, 111, ...  1993  2013
# 3                                  [113, 114, 115, 116]  2014   inf
# 4                                                 [112]  2011  2013
# ...                                                 ...   ...   ...
# 1062                                         [114, 115]  2015  2019
# 1063  [93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 10...  1973   inf
# 1064                                    [112, 113, 114]  2011  2017
# 1065                                    [114, 115, 116]  2015   inf
# 1066                                         [114, 115]  2015  2017
#
# [1067 rows x 9 columns]

# %% [markdown]
# ## Formatting dataframe

# %%
#Extracting last name
congress_member_info['last_name'] = congress_member_info['name'].apply(lambda x: x.split(",")[0])

# %%
#Scraping state abbreviations to create ID sometimes used in the congress.gov site
state_abbreviation_url = "https://docs.omnisci.com/v4.1.1/3_apdx_states.html"
response = requests.get(state_abbreviation_url).text
soup = BeautifulSoup(response, "html.parser")
state_abbreviation_lookup = pd.DataFrame()
col_names = ["state", "state_abbreviation"]

for state in soup.find("div", {"id":"us-state-abbreviations"}).find("tbody").find_all("tr"):
    state_pair = []
    for value in state.find_all("td"):
        state_pair.append(value.text.strip())
    to_add = pd.Series(state_pair, col_names)
    state_abbreviation_lookup = state_abbreviation_lookup.append([to_add], ignore_index=True)
state_abbreviation_lookup.head()
# Out:
#         state state_abbreviation
# 0     Alabama                 AL
# 1      Alaska                 AK
# 2     Arizona                 AZ
# 3    Arkansas                 AR
# 4  California                 CA

# %%
congress_member_info = pd.merge(congress_member_info, state_abbreviation_lookup, how='left', on='state')

# Removing delegates from guam, virgin islands, samoa, etc.
congress_member_info = congress_member_info[congress_member_info['state_abbreviation'].notna()]
# Out:
#       Unnamed: 0                name  \
# 0              0   Abercrombie, Neil
# 1              1  Abraham, Ralph Lee
# 2              2   Ackerman, Gary L.
# 3              3      Adams, Alma S.
# 4              4        Adams, Sandy
# ...          ...                 ...
# 1062        1062        Young, David
# 1063        1063          Young, Don
# 1064        1064         Young, Todd
# 1065        1065      Zeldin, Lee M.
# 1066        1066      Zinke, Ryan K.
#
#                                                     url       party  \
# 0     https://www.congress.gov/member/neil-abercromb...  Democratic
# 1     https://www.congress.gov/member/ralph-abraham/...  Republican
# 2     https://www.congress.gov/member/gary-ackerman/...  Democratic
# 3     https://www.congress.gov/member/alma-adams/A00...  Democratic
# 4     https://www.congress.gov/member/sandy-adams/A0...  Republican
# ...                                                 ...         ...
# 1062  https://www.congress.gov/member/david-young/Y0...  Republican
# 1063  https://www.congress.gov/member/don-young/Y000033  Republican
# 1064  https://www.congress.gov/member/todd-young/Y00...  Republican
# 1065  https://www.congress.gov/member/lee-zeldin/Z00...  Republican
# 1066  https://www.congress.gov/member/ryan-zinke/Z00...  Republican
#
#                state  district chamber  \
# 0             Hawaii         1   House
# 1          Louisiana         5   House
# 2           New York         5   House
# 3     North Carolina        12   House
# 4            Florida        24   House
# ...              ...       ...     ...
# 1062            Iowa         3   House
# 1063          Alaska  At Large   House
# 1064         Indiana         9   House
# 1065        New York         1   House
# 1066         Montana  At Large   House
#
#                                        congress_numbers  start     end  \
# 0     [102, 103, 104, 105, 106, 107, 108, 109, 110, ...   1991  2011.0
# 1                                       [114, 115, 116]   2015     inf
# 2     [103, 104, 105, 106, 107, 108, 109, 110, 111, ...   1993  2013.0
# 3                                  [113, 114, 115, 116]   2014     inf
# 4                                                 [112]   2011  2013.0
# ...                                                 ...    ...     ...
# 1062                                         [114, 115]   2015  2019.0
# 1063  [93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 10...   1973     inf
# 1064                                    [112, 113, 114]   2011  2017.0
# 1065                                    [114, 115, 116]   2015     inf
# 1066                                         [114, 115]   2015  2017.0
#
#         last_name state_abbreviation
# 0     Abercrombie                 HI
# 1         Abraham                 LA
# 2        Ackerman                 NY
# 3           Adams                 NC
# 4           Adams                 FL
# ...           ...                ...
# 1062        Young                 IA
# 1063        Young                 AK
# 1064        Young                 IN
# 1065       Zeldin                 NY
# 1066        Zinke                 MT
#
# [1060 rows x 12 columns]

# %%
#Getting representative ID for future match
congress_member_info['rep_id'] = [url.split("/")[-1:][0] for url in congress_member_info['url']]

# %%
#Combining last name and state abbreviation for future match
congress_member_info['last_name_state'] = congress_member_info['last_name'] + " (" + congress_member_info['state_abbreviation'] + ")"

# %%
congress_member_info.head()
# Out:
#    Unnamed: 0                name  \
# 0           0   Abercrombie, Neil
# 1           1  Abraham, Ralph Lee
# 2           2   Ackerman, Gary L.
# 3           3      Adams, Alma S.
# 4           4        Adams, Sandy
#
#                                                  url       party  \
# 0  https://www.congress.gov/member/neil-abercromb...  Democratic
# 1  https://www.congress.gov/member/ralph-abraham/...  Republican
# 2  https://www.congress.gov/member/gary-ackerman/...  Democratic
# 3  https://www.congress.gov/member/alma-adams/A00...  Democratic
# 4  https://www.congress.gov/member/sandy-adams/A0...  Republican
#
#             state district chamber  \
# 0          Hawaii        1   House
# 1       Louisiana        5   House
# 2        New York        5   House
# 3  North Carolina       12   House
# 4         Florida       24   House
#
#                                     congress_numbers  start     end  \
# 0  [102, 103, 104, 105, 106, 107, 108, 109, 110, ...   1991  2011.0
# 1                                    [114, 115, 116]   2015     inf
# 2  [103, 104, 105, 106, 107, 108, 109, 110, 111, ...   1993  2013.0
# 3                               [113, 114, 115, 116]   2014     inf
# 4                                              [112]   2011  2013.0
#
#      last_name state_abbreviation   rep_id   last_name_state
# 0  Abercrombie                 HI  A000014  Abercrombie (HI)
# 1      Abraham                 LA  A000374      Abraham (LA)
# 2     Ackerman                 NY  A000022     Ackerman (NY)
# 3        Adams                 NC  A000370        Adams (NC)
# 4        Adams                 FL  A000366        Adams (FL)

# %%
congress_member_info.to_csv("congress_110_116.csv")

# %% [markdown]
# ## Scraping Roll Call Info
#
# Each bill can be voted on a number of times, for every step of the legislative process and if ammendments are made. Each vote is referred to as a 'roll'.
#
# Congress.gov gives access to all recorded historic votes, which are readily available in a list format in their online database.
#
# Furthermore, the votes of each congress member is also available, which will be scraped later and used to create links.

# %% [markdown]
# First, we generate the links for each list of rolls, by looking at the structure of the website.

# %%
congress_urls = []
for year in range(2007,2021):
    congress_urls.append(f"https://clerk.house.gov/evs/{year}/index.asp")

print(congress_urls)
# Out:
# ['https://clerk.house.gov/evs/2007/index.asp', 'https://clerk.house.gov/evs/2008/index.asp', 'https://clerk.house.gov/evs/2009/index.asp', 'https://clerk.house.gov/evs/2010/index.asp', 'https://clerk.house.gov/evs/2011/index.asp', 'https://clerk.house.gov/evs/2012/index.asp', 'https://clerk.house.gov/evs/2013/index.asp', 'https://clerk.house.gov/evs/2014/index.asp', 'https://clerk.house.gov/evs/2015/index.asp', 'https://clerk.house.gov/evs/2016/index.asp', 'https://clerk.house.gov/evs/2017/index.asp', 'https://clerk.house.gov/evs/2018/index.asp', 'https://clerk.house.gov/evs/2019/index.asp', 'https://clerk.house.gov/evs/2020/index.asp']

# %% [markdown]
# Then, we extract the embedded links to all the rolls, such that we can later extract the data from them.

# %%
def get_roll_urls(congress_url):
    response = requests.get(congress_url).text
    soup = BeautifulSoup(response, "html.parser")
    
    roll_urls = []
    for a in soup.find("font", {"size": "3"}).find_all("a", href=True):
        roll_urls.append(congress_url[:-9] + a['href'].split(".")[0] + ".asp")
    
    return roll_urls

# %% [markdown]
# Finally, the scrape can be run for each roll, extracting the following information:
# * Year
# * Roll number (starting from 1 every year)
# * Issue (bill number)
# * Date of the vote
# * Question to be voted on
# * Result of the vote
# * Title/description
# * Link to the votes (to be used for further scraping)
# * Link to the page

# %%
roll_info = pd.DataFrame()
columns = ['Year','Roll', 'Issue','Date','Question','Result', 'Title/Description', 'Vote_link', 'Issue_link']

for congress_url in tqdm.tqdm(congress_urls):
    for roll_url in get_roll_urls(congress_url):        
        year = roll_url.split("/")[4]
        response = requests.get(roll_url).text
        soup = BeautifulSoup(response, "html.parser")
        for row in soup.find("table").find_all("tr"):
            if row.find_all("td"):
                line = []
                line.append(year)
                roll_link = 1
                for data in row.find_all("td"):
                    line.append(data.text.strip())
                    link = data.find("a")
                    if link and roll_link:
                        roll_link = 0
                        vote_link = link['href']
                    elif link:
                        issue_link = link['href']

                line.append(vote_link)
                line.append(issue_link)
                to_add = pd.Series(line, columns)
                roll_info = roll_info.append([to_add], ignore_index=True)

roll_info['Roll-id'] = roll_info['Year']+"-"+roll_info['Roll']
# Out:
# 100%|██████████████████████████████████████████| 14/14 [02:13<00:00,  9.55s/it]

# %%
#Link to be used for next scrape
roll_info['Vote_link_new'] = roll_info.apply(lambda row: "https://clerk.house.gov/Votes/" + str(row['Year']) + str(row['Roll']), axis=1)

# %%
roll_info.to_csv("roll_info.csv")

# %% [markdown]
# ## Scraping summaries
# For each unique issue (bill/resolution) we need to scrape summaries and committees.
#
# There may be many rolls for each issue, as the house needs to vote for each ammendment made, thus the summaries are the most recent ones.

# %%
#Preparing data
roll_info = pd.read_csv("roll_info.csv")

# %%
unique_issue_links = pd.DataFrame(roll_info['Issue_link'].unique()).rename(columns={0:'Issue_link'})
unique_issue_links['Issue_link'] = unique_issue_links['Issue_link'] + "/all-info"
unique_issue_links['Issue_link']
# Out:
# 0                      https://www.congress.gov/bill/110th-congress/house-bill/2764/all-info
# 1                      https://www.congress.gov/bill/110th-congress/house-bill/4040/all-info
# 2                     https://www.congress.gov/bill/110th-congress/senate-bill/2499/all-info
# 3                      https://www.congress.gov/bill/110th-congress/house-bill/3996/all-info
# 4                      https://www.congress.gov/bill/110th-congress/house-bill/3690/all-info
#                                                 ...
# 4284                   https://www.congress.gov/bill/116th-congress/house-bill/5078/all-info
# 4285    https://www.congress.gov/bill/116th-congress/house-concurrent-resolution/83/all-info
# 4286              https://www.congress.gov/bill/116th-congress/house-resolution/781/all-info
# 4287                   https://www.congress.gov/bill/116th-congress/house-bill/2881/all-info
# 4288              https://www.congress.gov/bill/116th-congress/house-resolution/779/all-info
# Name: Issue_link, Length: 4289, dtype: object

# %%
issue_info = pd.DataFrame()
cols = ['issue_link', 'committees', 'summary']

for issue_url in tqdm.tqdm(unique_issue_links['Issue_link'].iloc[3000:]):
  response = requests.get(issue_url).text
  soup = BeautifulSoup(response, "html.parser")

  relevant = soup.find("div", {"class":"main-wrapper all-info-wrapper"})
  if not relevant:
    continue

  #Getting committees
  committees = []
  if relevant.find("tr", {"class":"committee"}):
    for committee_row in relevant.find("table", {"class":"table_committee"}).find("tbody").find_all("tr", {"class":"committee"}):
      committees.append(committee_row.find("th").text.strip())

  #Getting latest summary
  latest_summary = relevant.find_next("div", {"id":"bill-summary"})
  #Take all paragraph tags and combine to a single string
  if not latest_summary:
    continue
  
  summary = " ".join([paragraph.text.strip() for paragraph in latest_summary.select("p")])

  to_add = pd.Series([issue_url, committees, summary], cols)
  issue_info = issue_info.append(to_add, ignore_index=True)

# %%
issue_info
# Out:
#                                                               committees  ...                                                                                              summary
# 0                                                          [House Rules]  ...
# 1                                                         [House Budget]  ...  Establishes the congressional budget for the federal government for FY2016 and sets forth budget...
# 2                    [House Veterans' Affairs, Senate Veterans' Affairs]  ...  Department of Veterans Affairs Budget Planning Reform Act of 2015 (Sec. 2) Directs the Secretary...
# 3                                                          [House Rules]  ...
# 4                                                [House Foreign Affairs]  ...  (This measure has not been amended since it was introduced. The summary of that version is repea...
# ...                                                                  ...  ...                                                                                                  ...
# 1267  [House Small Business, Senate Small Business and Entrepreneurship]  ...  Prison to Proprietorship Act This bill directs the Small Business Administration, in coordinatio...
# 1268                   [House Foreign Affairs, Senate Foreign Relations]  ...  This concurrent resolution directs the President to terminate the use of U.S. Armed Forces in ho...
# 1269                                                       [House Rules]  ...  This resolution sets forth the rule for consideration of H.Con.Res. 83 (directing the President ...
# 1270                  [House Energy and Commerce, House Foreign Affairs]  ...  Secure 5G and Beyond Act of 2020 This bill requires the President, in consultation with relevant...
# 1271                                                       [House Rules]  ...         This resolution sets forth the rule for consideration of H.R. 535 (PFAS Action Act of 2019).
#
# [1272 rows x 3 columns]

# %%
issue_info.to_csv("issue_info_3000_4288.csv")

# %% [markdown]
# ## Scraping Roll Call Votes

# %% [markdown]
# First, a dataframe is prepared to contain the scraping data with roll-ids as columns and member IDs as index

# %%
congress_member_info = pd.read_csv("congress_110_116.csv")
roll_info = pd.read_csv("roll_info.csv")
year = 2009

cols = roll_info[roll_info['Year'] == year]['Roll-id'].sort_values(ascending=False)
idx = congress_member_info['rep_id'].unique()

roll_call_vote = pd.DataFrame(index=idx, columns=cols)

# %%
roll_call_vote
# Out:
# Roll-id 2008-99 2008-98 2008-97 2008-96 2008-95 2008-94 2008-93 2008-92  \
# A000014     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# A000374     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# A000022     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# A000370     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# A000366     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# Y000066     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Y000033     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Y000064     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Z000017     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Z000018     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# Roll-id 2008-91 2008-90  ... 2008-107 2008-106 2008-105 2008-104 2008-103  \
# A000014     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# A000374     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# A000022     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# A000370     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# A000366     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# ...         ...     ...  ...      ...      ...      ...      ...      ...
# Y000066     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# Y000033     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# Y000064     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# Z000017     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# Z000018     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
#
# Roll-id 2008-102 2008-101 2008-100 2008-10 2008-1
# A000014      NaN      NaN      NaN     NaN    NaN
# A000374      NaN      NaN      NaN     NaN    NaN
# A000022      NaN      NaN      NaN     NaN    NaN
# A000370      NaN      NaN      NaN     NaN    NaN
# A000366      NaN      NaN      NaN     NaN    NaN
# ...          ...      ...      ...     ...    ...
# Y000066      NaN      NaN      NaN     NaN    NaN
# Y000033      NaN      NaN      NaN     NaN    NaN
# Y000064      NaN      NaN      NaN     NaN    NaN
# Z000017      NaN      NaN      NaN     NaN    NaN
# Z000018      NaN      NaN      NaN     NaN    NaN
#
# [969 rows x 690 columns]

# %% [markdown]
# Using the links previously extracted for the votes, we extract the vote for each member and store it in the dataframe.

# %%
for idx, row in tqdm.tqdm(roll_info[roll_info['Year'] == year].iterrows()):
    roll_vote_url = row['Vote_link_new']
    roll_id = row['Roll-id']

    response = requests.get(roll_vote_url).text
    soup = BeautifulSoup(response, "html.parser")
    tables = soup.find_all("table")
    
    try:
        for row in tables[1].find("tbody").find_all("tr"):
            try:
                rep_id = row.find("a", href=True)['href'][-7:]
            except:
                continue
            vote = row.find("td", {"data-label":"vote"}).text.strip()
            roll_call_vote[roll_id][rep_id] = vote
    except:
        continue

# %%
roll_call_vote.to_csv(f"roll_call_vote_{year}.csv")
